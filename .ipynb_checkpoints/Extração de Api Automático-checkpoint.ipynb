# %% [markdown]
# # Extração de API Automatico, Json para Csv e Visualização

# %%
from IPython.display import display, HTML
display(HTML("<style>.jp-OutputArea-output {display:flex}</style>")) #essa instalação permite barra de scroll horizontal  funcionar no Firefox
# Out:
# <style>.jp-OutputArea-output {display:flex}</style>

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
url='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters ={
    'start':'1',
    'limit':'15',
     'convert':'USD'
}
headers={
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
    #NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data

# If that didn't work try using the local host URL as shown in the video
# Out:
# {'status': {'timestamp': '2024-07-15T09:17:59.714Z', 'error_code': 0, 'error_message': None, 'elapsed': 45, 'credit_count': 1, 'notice': None, 'total_count': 9973}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11598, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
# Isso permite ver todas the columns, não apenas 15
#This allows you to see all the columns, not just like 15

#pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
# Isso normaliza os dados e faz ele mais bonito no dataframe
#This normalizes the data and makes it all pretty in a dataframe
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11598
# 1    1027     Ethereum    ETH      ethereum              9133
# 2     825  Tether USDt   USDT        tether             91564
# 3    1839          BNB    BNB           bnb              2192
# 4    5426       Solana    SOL        solana               701
# 5    3408         USDC   USDC      usd-coin             20956
# 6      52          XRP    XRP           xrp              1352
# 7   11419      Toncoin    TON       toncoin               458
# 8      74     Dogecoin   DOGE      dogecoin              1022
# 9    2010      Cardano    ADA       cardano              1212
# 10   1958         TRON    TRX          tron               999
# 11   5805    Avalanche   AVAX     avalanche               751
# 12   5994    Shiba Inu   SHIB     shiba-inu               844
# 13   6636     Polkadot    DOT  polkadot-new               792
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'symbol', 'slug', 'num_market_pairs', 'date_added',
#        'tags', 'max_supply', 'circulating_supply', 'total_supply',
#        'infinite_supply', 'platform', 'cmc_rank',
#        'self_reported_circulating_supply', 'self_reported_market_cap',
#        'tvl_ratio', 'last_updated', 'quote.USD.price', 'quote.USD.volume_24h',
#        'quote.USD.volume_change_24h', 'quote.USD.percent_change_1h',
#        'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d',
#        'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d',
#        'quote.USD.percent_change_90d', 'quote.USD.market_cap',
#        'quote.USD.market_cap_dominance', 'quote.USD.fully_diluted_market_cap',
#        'quote.USD.tvl', 'quote.USD.last_updated', 'platform.id',
#        'platform.name', 'platform.symbol', 'platform.slug',
#        'platform.token_address', 'timestamp'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 37 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  15 non-null     int64
#  1   name                                15 non-null     object
#  2   symbol                              15 non-null     object
#  3   slug                                15 non-null     object
#  4   num_market_pairs                    15 non-null     int64
#  5   date_added                          15 non-null     object
#  6   tags                                15 non-null     object
#  7   max_supply                          4 non-null      float64
#  8   circulating_supply                  15 non-null     float64
#  9   total_supply                        15 non-null     float64
#  10  infinite_supply                     15 non-null     bool
# ...

# %%
df.dtypes
# Out:
# id                                             int64
# name                                          object
# symbol                                        object
# slug                                          object
# num_market_pairs                               int64
# date_added                                    object
# tags                                          object
# max_supply                                   float64
# circulating_supply                           float64
# total_supply                                 float64
# infinite_supply                                 bool
# platform                                     float64
# cmc_rank                                       int64
# self_reported_circulating_supply             float64
# self_reported_market_cap                     float64
# tvl_ratio                                     object
# last_updated                                  object
# quote.USD.price                              float64
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data

#Use isso se você apenas quer manter-lo no dataframe 
        # Use this if you just want to keep it in a dataframe
   # df2 = pd.json_normalize(data['data'])
    #df2['timestamp'] = pd.to_datetime('now')
    #df= pd.concat([df,df2])
    
    # Use this if you want to create a csv and append data to it
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df
    
    if not os.path.isfile(r'C:\Users\aj2co\jupyter\API.csv'):
        df.to_csv(r'C:\Users\aj2co\jupyter\API.csv', header='column_names')
    else:
        df.to_csv(r'C:\Users\aj2co\jupyter\API.csv', mode='a', header=False)
        
    #Then to read in the file:
       #df = pd.read_csv(r'C:\Users\aj2co\jupyter\API.csv')
        
# If that didn't work try using the local host URL as shown in the video

# %%
df = pd.read_csv(r'C:\Users\aj2co\jupyter\API.csv')
df
# Out:
#     Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0            0      1      Bitcoin    BTC       bitcoin             11597
# 1            1   1027     Ethereum    ETH      ethereum              9132
# 2            2    825  Tether USDt   USDT        tether             91528
# 3            3   1839          BNB    BNB           bnb              2192
# 4            4   5426       Solana    SOL        solana               701
# 5            5   3408         USDC   USDC      usd-coin             20950
# 6            6     52          XRP    XRP           xrp              1352
# 7            7  11419      Toncoin    TON       toncoin               458
# 8            8     74     Dogecoin   DOGE      dogecoin              1022
# 9            9   2010      Cardano    ADA       cardano              1212
# 10          10   1958         TRON    TRX          tron               999
# 11          11   5805    Avalanche   AVAX     avalanche               751
# ...

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner Completdo')
    sleep(60) #esperapor 1 minuto
exit()
# Out:
# API Runner Completdo
# API Runner Completdo
# API Runner Completdo
# API Runner Completdo
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 8
#       6     api_runner()
#       7     print('API Runner Completdo')
# ----> 8     sleep(60) #esperapor 1 minuto
#       9 exit()
#
# KeyboardInterrupt:

# %%
dfapi = pd.read_csv(r'C:\Users\aj2co\jupyter\API.csv')
dfapi
# Out:
#     Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0            0      1      Bitcoin    BTC       bitcoin             11597
# 1            1   1027     Ethereum    ETH      ethereum              9132
# 2            2    825  Tether USDt   USDT        tether             91528
# 3            3   1839          BNB    BNB           bnb              2192
# 4            4   5426       Solana    SOL        solana               701
# 5            5   3408         USDC   USDC      usd-coin             20950
# 6            6     52          XRP    XRP           xrp              1352
# 7            7  11419      Toncoin    TON       toncoin               458
# 8            8     74     Dogecoin   DOGE      dogecoin              1022
# 9            9   2010      Cardano    ADA       cardano              1212
# 10          10   1958         TRON    TRX          tron               999
# 11          11   5805    Avalanche   AVAX     avalanche               751
# ...

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11598
# 1    1027     Ethereum    ETH      ethereum              9133
# 2     825  Tether USDt   USDT        tether             91564
# 3    1839          BNB    BNB           bnb              2192
# 4    5426       Solana    SOL        solana               701
# 5    3408         USDC   USDC      usd-coin             20956
# 6      52          XRP    XRP           xrp              1352
# 7   11419      Toncoin    TON       toncoin               458
# 8      74     Dogecoin   DOGE      dogecoin              1022
# 9    2010      Cardano    ADA       cardano              1212
# 10   1958         TRON    TRX          tron               999
# 11   5805    Avalanche   AVAX     avalanche               751
# 12   5994    Shiba Inu   SHIB     shiba-inu               844
# 13   6636     Polkadot    DOT  polkadot-new               792
# ...

# %%
# One thing I noticed was the scientific notation. I like it, but I want to be able to see the numbers in this case
# Uma coisa eu notei foi a notação científica. Eu quero ser capaz de ver os numeros neste caso

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11597
# 1    1027     Ethereum    ETH      ethereum              9132
# 2     825  Tether USDt   USDT        tether             91528
# 3    1839          BNB    BNB           bnb              2192
# 4    5426       Solana    SOL        solana               701
# 5    3408         USDC   USDC      usd-coin             20950
# 6      52          XRP    XRP           xrp              1352
# 7   11419      Toncoin    TON       toncoin               458
# 8      74     Dogecoin   DOGE      dogecoin              1022
# 9    2010      Cardano    ADA       cardano              1212
# 10   1958         TRON    TRX          tron               999
# 11   5805    Avalanche   AVAX     avalanche               751
# 12   5994    Shiba Inu   SHIB     shiba-inu               844
# 13   6636     Polkadot    DOT  polkadot-new               792
# ...

# %%
# Now let's look at the coin trends over time
#Agora vamos olhar na tendencia do coin atravvez do tempo

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.27733                       4.27922
# Ethereum                         0.55108                       3.07167
# Tether USDt                      0.00914                      -0.00087
# BNB                              0.55752                       3.07035
# Solana                          -0.34499                       5.29312
# USDC                             0.00797                       0.00031
# XRP                             -0.33399                      -0.08335
# Toncoin                          0.26661                       1.42132
# Dogecoin                         0.99181                       3.48147
# Cardano                         -1.31405                      -1.60154
# TRON                            -0.25698                      -2.00749
# Avalanche                        0.44287                       2.62142
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h      0.27733
#              quote.USD.percent_change_24h     4.27922
#              quote.USD.percent_change_7d      7.97045
#              quote.USD.percent_change_30d    -7.46226
#              quote.USD.percent_change_60d    -7.91300
#              quote.USD.percent_change_90d    -3.71730
# Ethereum     quote.USD.percent_change_1h      0.55108
#              quote.USD.percent_change_24h     3.07167
#              quote.USD.percent_change_7d      9.94557
#              quote.USD.percent_change_30d    -6.13984
#              quote.USD.percent_change_60d     7.64236
#              quote.USD.percent_change_90d     4.24874
# Tether USDt  quote.USD.percent_change_1h      0.00914
#              quote.USD.percent_change_24h    -0.00087
#              quote.USD.percent_change_7d      0.04789
#              quote.USD.percent_change_30d     0.08235
#              quote.USD.percent_change_60d    -0.01869
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h    0.27733
#             quote.USD.percent_change_24h   4.27922
#             quote.USD.percent_change_7d    7.97045
#             quote.USD.percent_change_30d  -7.46226
#             quote.USD.percent_change_60d  -7.91300
#             quote.USD.percent_change_90d  -3.71730
# Ethereum    quote.USD.percent_change_1h    0.55108
#             quote.USD.percent_change_24h   3.07167
#             quote.USD.percent_change_7d    9.94557
#             quote.USD.percent_change_30d  -6.13984
#             quote.USD.percent_change_60d   7.64236
#             quote.USD.percent_change_90d   4.24874
# Tether USDt quote.USD.percent_change_1h    0.00914
#             quote.USD.percent_change_24h  -0.00087
#             quote.USD.percent_change_7d    0.04789
#             quote.USD.percent_change_30d   0.08235
#             quote.USD.percent_change_60d  -0.01869
# ...

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
#Because of how it's structured above we need to set an index. I don't want to pass a column as an index for this dataframe
#So I'm going to create a range and pass that as the dataframe. You can make this more dynamic, but I'm just going to hard code it


index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
#df6 = df5.set_index(index)
df6=df5.reset_index()
df6

# If it only has the index and values try doing reset_index like "df5.reset_index()"
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.27733
# 1       Bitcoin  quote.USD.percent_change_24h   4.27922
# 2       Bitcoin   quote.USD.percent_change_7d   7.97045
# 3       Bitcoin  quote.USD.percent_change_30d  -7.46226
# 4       Bitcoin  quote.USD.percent_change_60d  -7.91300
# 5       Bitcoin  quote.USD.percent_change_90d  -3.71730
# 6      Ethereum   quote.USD.percent_change_1h   0.55108
# 7      Ethereum  quote.USD.percent_change_24h   3.07167
# 8      Ethereum   quote.USD.percent_change_7d   9.94557
# 9      Ethereum  quote.USD.percent_change_30d  -6.13984
# 10     Ethereum  quote.USD.percent_change_60d   7.64236
# 11     Ethereum  quote.USD.percent_change_90d   4.24874
# 12  Tether USDt   quote.USD.percent_change_1h   0.00914
# 13  Tether USDt  quote.USD.percent_change_24h  -0.00087
# 14  Tether USDt   quote.USD.percent_change_7d   0.04789
# 15  Tether USDt  quote.USD.percent_change_30d   0.08235
# ...

# %%
# Change the column name



df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.27733
# 1       Bitcoin  quote.USD.percent_change_24h   4.27922
# 2       Bitcoin   quote.USD.percent_change_7d   7.97045
# 3       Bitcoin  quote.USD.percent_change_30d  -7.46226
# 4       Bitcoin  quote.USD.percent_change_60d  -7.91300
# 5       Bitcoin  quote.USD.percent_change_90d  -3.71730
# 6      Ethereum   quote.USD.percent_change_1h   0.55108
# 7      Ethereum  quote.USD.percent_change_24h   3.07167
# 8      Ethereum   quote.USD.percent_change_7d   9.94557
# 9      Ethereum  quote.USD.percent_change_30d  -6.13984
# 10     Ethereum  quote.USD.percent_change_60d   7.64236
# 11     Ethereum  quote.USD.percent_change_90d   4.24874
# 12  Tether USDt   quote.USD.percent_change_1h   0.00914
# 13  Tether USDt  quote.USD.percent_change_24h  -0.00087
# 14  Tether USDt   quote.USD.percent_change_7d   0.04789
# 15  Tether USDt  quote.USD.percent_change_30d   0.08235
# ...

# %%
# !pip install seaborn --upgrade
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: C:\Users\aj2co\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip
# ...

# %%
df7['percent_change']=df7['percent_change'].replace(['quote.USD.percent_change_1h'], ['1h'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h   0.27733
# 1       Bitcoin            24h   4.27922
# 2       Bitcoin             7d   7.97045
# 3       Bitcoin            30d  -7.46226
# 4       Bitcoin            60d  -7.91300
# 5       Bitcoin            90d  -3.71730
# 6      Ethereum             1h   0.55108
# 7      Ethereum            24h   3.07167
# 8      Ethereum             7d   9.94557
# 9      Ethereum            30d  -6.13984
# 10     Ethereum            60d   7.64236
# 11     Ethereum            90d   4.24874
# 12  Tether USDt             1h   0.00914
# 13  Tether USDt            24h  -0.00087
# 14  Tether USDt             7d   0.04789
# 15  Tether USDt            30d   0.08235
# 16  Tether USDt            60d  -0.01869
# 17  Tether USDt            90d   0.00874
# 18          BNB             1h   0.55752
# 19          BNB            24h   3.07035
# 20          BNB             7d   9.73791
# 21          BNB            30d  -9.14878
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],
                                                      ['24h','7d','30d','60d','90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h   0.27733
# 1       Bitcoin            24h   4.27922
# 2       Bitcoin             7d   7.97045
# 3       Bitcoin            30d  -7.46226
# 4       Bitcoin            60d  -7.91300
# 5       Bitcoin            90d  -3.71730
# 6      Ethereum             1h   0.55108
# 7      Ethereum            24h   3.07167
# 8      Ethereum             7d   9.94557
# 9      Ethereum            30d  -6.13984
# 10     Ethereum            60d   7.64236
# 11     Ethereum            90d   4.24874
# 12  Tether USDt             1h   0.00914
# 13  Tether USDt            24h  -0.00087
# 14  Tether USDt             7d   0.04789
# 15  Tether USDt            30d   0.08235
# 16  Tether USDt            60d  -0.01869
# 17  Tether USDt            90d   0.00874
# 18          BNB             1h   0.55752
# 19          BNB            24h   3.07035
# 20          BNB             7d   9.73791
# 21          BNB            30d  -9.14878
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#g=sns.FacetGrid(df7, row='percent_change', col= 'values')
sns.catplot( x='percent_change', y= 'values', hue='name', data=df7, kind='point')

# %%
print(sns.__version__)
# Out:
# 0.13.2

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#        name  quote.USD.price                   timestamp
# 0   Bitcoin      60982.46901  2024-07-14 19:33:54.598552
# 15  Bitcoin      60997.00465  2024-07-14 19:34:57.933378
# 30  Bitcoin      60997.00465  2024-07-14 19:35:58.838493
# 45  Bitcoin      60995.61163  2024-07-14 19:36:59.428793

# %%
sns.set_theme(style='darkgrid', font_scale=0.7   )
sns.lineplot(x='timestamp', y='quote.USD.price', data = df10 )
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
